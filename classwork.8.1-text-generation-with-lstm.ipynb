# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np
import codecs

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = codecs.open(path, "r", "utf-8").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 187s 935us/step - loss: 1.9870
# --- Generating with seed: "t only
# permitted to make this attempt, it is commanded by th"
# ------ temperature: 0.2
# t only
# permitted to make this attempt, it is commanded by the a consequence of the the greater and sense of the great the the consequence of the conscious and subjection of the the intermate of the morality there when which the great the the sense of the the serrity of the histerment the reader of him of the conscience of the besting the there is the interpater and soul, the the regarded the great the properved and sense of the consequent and the are of th
# ------ temperature: 0.5
#  the properved and sense of the consequent and the are of the dengance of the presence of the great one of the pleasure of serrate, there senses of the serration ensens and in the beception of one's learnt the in the read them there
# is good one and him estence of unlow to
# stould all one frot are of serfing exception of the high ent of a reader of the dount that german and one has exception, and since and still greations of the refine of a thing all of the
# ------ temperature: 1.0
# nce and still greations of the refine of a thing all of the we lifes senter organifuly will
# tyuth succe thathilitiblt storlatical zermanty accennek, which he imen to weakn grea ald which become, him itnells, of enough thear
# one came eedee orns o. world with werl, as will
# shorver., and a regress or one bund are ma tempianting their as, "he which val and in sroprosing preteduce and condstent, we implatny and
# bad
# appen willer-desation. our and this ong thand.
# ------ temperature: 1.2
# latny and
# bad
# appen willer-desation. our and this ong thand. stypless, whilh incnawy alowill, thar
# heince, interracicity, bepleotl, noble hereqoater of highurted.
#
# s cle forctly, there) is mokenged.
# it that the
# r vorgityoried) seecly hyasily now be nefeme kups "ilmorings,
# and theneaxtune of
# heminaused
# thoiwh." stance,, if the gearity
# ole hears they bey
# caunce of asturely tope, is here in defile when wellely ge; them ho creath in
# our to hait ily stiined mor
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 170s 848us/step - loss: 1.6296
# --- Generating with seed: "ng and roaming--for he is as
# restless and aimless in his cou"
# ------ temperature: 0.2
# ng and roaming--for he is as
# restless and aimless in his could be a sense for the reason--and a have the sense of the reason and the sense of the more the pertain and the play the pertain the sense of the sense of the sense of the really the more pertain and the sense of the philosophy of the philosophy of the dest the intered the sense of the part of the sense of the conscience of the pertain the philosophy of the sense of the reason and the pursion in th
# ------ temperature: 0.5
#  philosophy of the sense of the reason and the pursion in the spirit and the part, the invertent beton in the contempt of the leadn as a dee new the self-cand cast them in the philosophy and the reverent of the reason in the respect of the treasition and to the pertain deception of the have a hast the partane and deception and all the seems to the purtial being the endured
# more the does perhaps the henety discerrive durptical to been the purile and play to
# ------ temperature: 1.0
# e henety discerrive durptical to been the purile and play to
# excitute reason,
# we doverstheling to a chould is it, the
# spirit epins," has lyattife,
# be vieward as motilihyarl: form to mitality him thood handserst, sympatucate: the belwet, heeft, the pertual;
# through uncave of a kenecogan that, where gonening-and whatherly present harse hemplast.
# "perhapon for megorgere of cartain lew presen actate other that the enstall pertains in the part to an olvanation
# ------ temperature: 1.2
# ther that the enstall pertains in the part to an olvanation as whichge oth pussity, and a
# tsicatifl
# a keplets the daits
# meditally cleared to which learn, in his one of perioding bither, and
# repardent
# by the genery of.
#  . another "mirits fect, they cand sings among has revalop,, and them, it away the
# arrepossite from in evilep it wever as
# reason--and under the saff there", means--thereness, and vid
# iater of usenful. ilson,--last, thereverty of moois. anoth
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 185s 925us/step - loss: 1.5383
# --- Generating with seed: "heir satisfaction with the actual world in which they find i"
# ------ temperature: 0.2
# heir satisfaction with the actual world in which they find is a seems that is a souls that is a still and such a superity and a seems that is a seems the same the same the order to depressities and the are a serrication of the same the same the self-consideration of the will the same the same the mankind of the strong the sense of the are a shorth and the presence and the promaticity of the self the same the presence of the self the strong the same the str
# ------ temperature: 0.5
# he same the presence of the self the strong the same the strong of the same through his instincts and progress of the contempent and always all the generality and all the or the once of the actions of the interpretations of the worth and as a think the must one has the privise, the and degree and exist in the consequences of the such a morality of the instinct and distietic s himself and that the circumstances of the sight to himself to an according the gr
# ------ temperature: 1.0
# circumstances of the sight to himself to an according the grow disternce all this actions
# and the world to good, here what is affectifituce infeided antsly everations than that the inspeat sees and the word from say.n
# hawh and conscious things
# good of soult--it schopceon. the strong opinion as a stipes as with vae realich mschanaiys
# is
# than a new recounls by fearss olared that wherevertokarg,onicism, thinks-from the eassisf-strange unwort, divinces restres
# ------ temperature: 1.2
# sm, thinks-from the eassisf-strange unwort, divinces restrest, woragine, or in likely poful. wapperices, unevusiousnestmensperonge knowleventure results of makiny, ferients to subrin of
# sy torth one's veryfore, hay not ass the resistsong or the
# gruths one nothois fapt, has aures; butfrimany-ngwist, and may, has of this proknonularing it oper'sepressed more effer bythraknaing that
# all rea or, lime--bor .. himself agree a ma) poluan" the kinding.; sthol.s no
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 176s 878us/step - loss: 1.4935
# --- Generating with seed: "ly not without some danger--get an idea of what people
# actua"
# ------ temperature: 0.2
# ly not without some danger--get an idea of what people
# actually to the same and the present to has an enthe the interpretation of the reason of the suffering to the present to the seems to the seems to the seems to the seems to be and the same and reverse of the soul of the present to be and individual supposed to the fact to the seems to the seems to distinguished to the seems to the present to be and with the same and the stronger and the same and the mo
# ------ temperature: 0.5
# e and with the same and the stronger and the same and the most feels the same as a moral with right, and with good to contlaks he is a most bad all the possible of which a person of the preitially
# delicate with of moral man suspect to have not to forms which the pain of the do the sense to as a science of the soul of the process in all the man who every of the every man so now must to be as not assume to all the intered to the present to be desire mankind
#
# ------ temperature: 1.0
# sume to all the intered to the present to be desire mankind
# suppoffuly y more for propuration of the see cases. escound of discentainedy, of inswuse as rang tos and presentuly pite in or to pleade, of "present of the thinges to understand anyarily follow beturatomed of
# this thought distruturines; in the implems as all was
# believe, a man and doesto the away by wtiler affouran them, no laystor
# noh to responcical cause have south,
# the exolte: in the (us not h
# ------ temperature: 1.2
# o responcical cause have south,
# the exolte: in the (us not hearity. german need (oghaticing scave allified rasning
# to sinklof menricly, as he seconbavoused sary, morals.
#       kaptyy
# servarl of valuatitad susts enjoyselner, of in alloract,ly fundgenessely,
# that digdar"n
# seek is ay no livisagary.=--an to-ttrud. could indowfe, with gultidly redulty has, burder are taste) "to orial" mumble exparliser
# ideased fren
# thest, or "goy in their harby past are voncew?
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 167s 835us/step - loss: 1.4627
# --- Generating with seed: "eneration, which has inherited as it were different standard"
# ------ temperature: 0.2
# eneration, which has inherited as it were different standard the sense of the stronger the sensition of the same the spirit of the spirit of the promise the belief in the are and and the sensition of the considered to a states of the stronger to language and all the present to the sense of the spirit the spirit and the feeling that the sense of the sense of the spirit in the sense of the success of the morality of the profore and success of the prover the
# ------ temperature: 0.5
# f the morality of the profore and success of the prover the distingung and the feeling that the imperty of the spirit
# the philosophers and moral and in a powerful and is use the state of the mistern spirit of readine to great pleasure to which he wisd and placentic that the spirit of the taste, and the state of the promater of the sensible to full the wance something in his advantism which all philosophers and the delight the sting of the powerful in the c
# ------ temperature: 1.0
# losophers and the delight the sting of the powerful in the ceate of europe not followed are the spirit propereted and condition is simultoriatic wartonning, in rearth the feeling existence and hied to can
# formus and the spirited comition could be ade"--prehessial.tian and conditions. it is protely rually suiride
# life from f eedould
# but more to mestang of "mandilinals, obligets of german consequences, is the standing; it is whol, spirited the naturesm and u
# ------ temperature: 1.2
# es, is the standing; it is whol, spirited the naturesm and un-bissenck this greater, utic as blosi all seopla, personilia liffined with perhaps and sextance be fast and
# typecument manmeresadly. it, pittic.
#
# occatiests--weerffamence,
# as howrow surfait,
# a not rilogy of him sudaur and springle.ally shoigh consinted allizistswoicious ettucents; ans tide insentigense boek who cause and to
# indibalater childcy utnefulant t
# greligard
# for  sorrlieve exissie -which
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 160s 799us/step - loss: 1.4411
# --- Generating with seed: "pense of
# justice and why are such beautiful things spoken of"
# ------ temperature: 0.2
# pense of
# justice and why are such beautiful things spoken of the senses of the same some the senses of the every constitutes and all the same the same and some instinct of the senses there is the subtle to the same the senses in the satisfices there are the same the senses of the same the same the same states the senses of the same and there is all the senses there is all the conscious and all the same and some the conscious and some the conscious and some
# ------ temperature: 0.5
#  same and some the conscious and some the conscious and some himself that is there in the philosophers--and are of all all the same and almost soul and acted in the senticion of the same as his understand previorate in the religious conscious attained to longer and there are reality in the same only conscious and its do the commands of his man must religious for himself as a shems of the call for them, and is conscious.
#
# 111. the aristocrationful and disti
# ------ temperature: 1.0
# them, and is conscious.
#
# 111. the aristocrationful and distide" al ost itter. the german
# everys. but beliefs made not believe is nobleddent to the standposisc, and
# origin, man for done--un!--  is virtueent.--the extragrined
# that is ful "morality.
#
#       : "satiliening "unmodible, their obedious for the deferations, if them infecence
# in a fancalism, it is refinement of toem somemical tracis, at can all active listen takes a fugute. as a midint, where less a
# ------ temperature: 1.2
#  all active listen takes a fugute. as a midint, where less are! evficial-cast "wholly such dy they burnue marky assumplived engidurent.--spons--for heal,
# chall remainty and hatabrity.
# to beauis.
#
# 18. the great not vanitable go
# birder
# i vant-to been one lashols.--but furd"" of, rep sy!--constisuli-whith even nor relable what comoun laugh reing whoeverto-uith.
# 2derate philosopher,
# let the-wortes and masterly," as every and premans
# is therekwit may ortrimaty,
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 171s 852us/step - loss: 1.4262
# --- Generating with seed: "t whom moralists are silent. perhaps
# severity and craft are "
# ------ temperature: 0.2
# t whom moralists are silent. perhaps
# severity and craft are the present can be a supers of the strange of the same and conscience, and all the breaking and strength and the strength and more in the present to any one must be a soul of the strange and the spirit in the same and the acts of the scientific the present and the strength of the strength and moral supersting the present condection and so the same and so the present allow the same and the morality
# ------ temperature: 0.5
#  the same and so the present allow the same and the morality and
# reference of the instination of the instination of the condent the man with the sign to a che(comes of the way and look of the spirit or and once one perhaps the respections be a franter as a prover of the later with the strengther as much of the religious and circumsclessive emotions of the sape of the strengther and to be a short, the moral religious are it the greatest of the our the salva
# ------ temperature: 1.0
# the moral religious are it the greatest of the our the salvation
# lose it grost, and lift that an same learned: the wayly, pains. the philosophy in even when before it eyes possible of it will it is enitroging
# is no judgment
# xposern, the sopel acquire have be all the man valud me their
# present insancent
# is only
# vicouerly and less force of the
# profly compremined with our know nive the ), how out of provence and his
# gain much of emotionsow tree cyatice, and a
# ------ temperature: 1.2
# provence and his
# gain much of emotionsow tree cyatice, and angrantenes, baines,
# bood
# ourselve why one
# a wild follow the putusume tistering verative compresse of
# herits onms to lose ste. on
# geury
# fore!
# him judgment flest prilogical baftation where as a vispon through a vencely" to untto self-minedd is clo"ing: and hature these
# make pompouction, flest race
# hatistoy-argutamly circumshroitw for the
# mas dreagenes orreflicing ocretive growing but a munt had real
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 162s 807us/step - loss: 1.4118
# --- Generating with seed: " reputation as a people of depth for prussian "smartness," a"
# ------ temperature: 0.2
#  reputation as a people of depth for prussian "smartness," and the significance of the sense of the same all the sense of the same the sense of the superior and and the sense of the sense of the same to the sense of the same taste of the same and the sense of the sense of the sense of the still and something is a condition of the sense of the sense of the standard to the sense of the sense of the sense of the same all the free spirit of the sense of the se
# ------ temperature: 0.5
# sense of the same all the free spirit of the sense of the sense of the philosophers of the same one look and when the germanism that it is precisely and many more necessity of the freedom of with the intellectually man has force of the worst only to the slang at the same decess and more down into the many for which all the most personal condition of the same all the believed to the contraids of the faculty in the origed to condition of the worst present wi
# ------ temperature: 1.0
# e faculty in the origed to condition of the worst present with its avaring trush
# encomely, and finds wisled--and be concealed teacing origin, and recall under their  uss an enough and sate in the -flaity to a loug out our ersish human liess of period heaving and philosophical metaphysical man one, being itself.
#
# entificulaten of to confeted to all
# perhaps accumured itself that is self-aristof with answardmed and joy meties as
# couming the conmust learned.
#
#
# ------ temperature: 1.2
#  answardmed and joy meties as
# couming the conmust learned.
#
#
# 1ihe him, too antair
# noting now
# still the suppocate
# of a jest to's life; first n
# which me happiness a ma law with the undenedent to his treevat viratinateons reputumsely away to ony vie
# avoughs but
# exonect,
#
#
# uticlos oneuthable fins dsations clears, mediorkations)
# fore, fragrrund hen--a hat affords dispoces. one been rety, (are degreemsely
# gutter and cails--every confairy to the disful wonsens
# sy
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 158s 788us/step - loss: 1.3997
# --- Generating with seed: "mething dreadful also.
#
# 90. heavy, melancholy men turn light"
# ------ temperature: 0.2
# mething dreadful also.
#
# 90. heavy, melancholy men turn light to the probleness, and means of the conscience of the farth of the sense of the conscience of the disposition of the disposition of the disposition of the sense of the conscience of the disposition of the same and soul and explaniness of the same disposition and conscience of the same concerning the self-conscience and and problem of the sense of the presence of the world of the religion of the d
# ------ temperature: 0.5
#  sense of the presence of the world of the religion of the definition and controld of his commond the conceiving of the precises and pain the instinct of the same and the astrey conceptions. existenced and will and souls, towards and can not the conscience of arding of a sould of the most proposition and attain and pleasure presence of present and bad and conscience of into religion that the cincumpent of laberty and and lard means to its contrary and pred
# ------ temperature: 1.0
# mpent of laberty and and lard means to its contrary and predity and pall. and
# meran by
# we hinds--and the out into from copon it somethers with a have an europe
# who has deat
# seems the advantired from a feeled
# fulosed, the artist and air and religious ourselves
# strong forming are the transgoring, from a wasted arogreble qualy to eye eurakes to-what heal
# ta.--forppetres saffing how conscientials,. conscience, when the youn more error a till essentially , has
# ------ temperature: 1.2
# nscience, when the youn more error a till essentially , has certain apritude -this done--with exafted--that their pari
# pious, and pnes-gived with min understand exceps and lightiness, there is unfeather, deating and on,
# now above the palm towards therefore, the
# presence exetfers, we the perceptoverc" who prezapess and religion of musher, elests
# vanity,
# ne ime--was good astre justmlat doven fask of things! aware cannot
# one estime,
# delitarity of gemain,
# as
# t
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 159s 796us/step - loss: 1.3895
# --- Generating with seed: " "why is belief in such judgments
# necessary?"--in effect, it"
# ------ temperature: 0.2
#  "why is belief in such judgments
# necessary?"--in effect, it is a sense of the strength and present spirituality and present desires of the soul and the sense of the precisely the soul one has precisely the present spirituality and the states of the sense of the extent of the strength and profound and states of the spirituality of the strength a soul be a conduct of the most general sense of the present the soul and opinion of the sense of the spirituality
# ------ temperature: 0.5
# resent the soul and opinion of the sense of the spirituality, but the believes of the mingling; the more and more and the conduct in the conduct and sense of the spriristic and possess of the belief to the different propernane in a schopenhns, which we person of the conscious a not only one and time the stood and a profound of the spirit in the supremesticulated as the least all the precisely
# man of the future, the new the democratic and visity of the natu
# ------ temperature: 1.0
# of the future, the new the democratic and visity of the nature of the dealitumene in
# the sense of "the solitual mestance, as toese clanaly form without said all figves: this even and pastive and apid. which phenoper sakestinm, there is the oppicate, is he finds fool as his fron. who desired lawble rodes. this is s and finally are advanteres for impulsisor repust of ranking: an actorion. the judge of the perceivities.tic purpose of sporption, for orgiohs oe
# ------ temperature: 1.2
# of the perceivities.tic purpose of sporption, for orgiohs oecones doestoupintrification onivilys.
#
# o
#
#    acine findly tos an it of their a standerly awatilritic is deprance which has enlsun inscises to the paungess of ?liketraid, treats pry onun.
# prythy happinebing; thousand, the conduct
# abserty we innecity, had a kindance of the conduct extene gacsaw invagual; as if povereng exist in keen, only but free
# the even free musicular forcious bher the not
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 187s 933us/step - loss: 1.3809
# --- Generating with seed: "he reins, the
# spiritual and corporeal licentia morum in the "
# ------ temperature: 0.2
# he reins, the
# spiritual and corporeal licentia morum in the strange and the spiritual spect of the spiritual stronger and spiritual species of the fact the interpretation of the spirit and and and the fact and most species the problem of the conscience of the spirit of the same the most and the present man in the same the sense of the stranger and the former strange of the strange and the stranges and free spirit and sublime and and the spiritual strange o
# ------ temperature: 0.5
#  and free spirit and sublime and and the spiritual strange of stript soul, and the most sufficient moral and friends, which is the assumation of philosophers, or lives of species of the tranking in the self self-philosophy and mysterious prestr. and such a discipling and concerned and man share as a strong of intellectual
# promises and states, and are precisely and reason of men of its spiritual to a be a man wishe, without a doubl super of the sentiments,
# ------ temperature: 1.0
#  a be a man wishe, without a doubl super of the sentiments, not of moral, affonsthing and closed present-depease seek man opin. the have turdies ofu the fusid? the too "spion of is noble,
# namely gain and master eved, which it they true finertulal functor it and what it is attenue touch of bland focrumed an emulity of yet have only of means it peoples jiginkneval dis-delithenes is no, and is a consciations or and what one has
# so in"eval
# conscience, hached
# a
# ------ temperature: 1.2
# ciations or and what one has
# so in"eval
# conscience, hached
# a suffered inperpous losy los the
# book.
#
#
#
#
# 2        1. )qualiors even does it, in the wupt them man. whether souginatiom cas we shall
# sya. they extenty of rajuse the hostiful firet the conceres obur of the yeys shord evirlimed clast in them lenty in new will fundamental "nature of traimed in falme
# or its
# levis actions notwormath
# fins to many externaniese truth without different wright
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 188s 939us/step - loss: 1.3715
# --- Generating with seed: "low," there is certainly something unteachable,
# a granite of"
# ------ temperature: 0.2
# low," there is certainly something unteachable,
# a granite of the same there is a sense of the sense of the sense of the sense of the consentions of the sense of the sense of the sense of the sense of the consentions of the sentiments of the consentions of the sense of the sense of the sense of the sense of the strength there is a sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of th
# ------ temperature: 0.5
# se of the sense of the sense of the sense of the sense of the intellectual and person is the entire and something and life is a more contentional
# senses of the surposism. one of the sentiments, and so that the
# sentiments and finds as an accustomed as consequence is something of the earthled been the conditioned and state of the sense of over
# consequence of the sense of the later, and the conscience of its politice is a desentions therefore an englished tha
# ------ temperature: 1.0
# e of its politice is a desentions therefore an englished than poosises. how timent. let us nothing,--in his riched ials, they are really
# sict and bey and hitherto
# possernce is, that greater with traienance of sin into
# me, as in this delicate fore; and he tale, how make certainly phenomenre is nom all thereoular one should otherw, understined and witny? achied siteds
# it is cra"unce sonners for those and undivide, ontestrures and
# growherers: threedism. may i
# ------ temperature: 1.2
# e and undivide, ontestrures and
# growherers: threedism. may it ishes no sweal-indirined moral rekgode origin, eay abifedf, in they curalting.
#   encessenifiincess and knew fore, no decided no slang,
#
#
# 1treat
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# a "nething
# satisfifity emideser--refenschings in
# truthqued" loved, long
# upmoratic which aushow hartuin." of such only
# if the self supposers. ther ourselvess a flein-sccting assumen useful natural;
# they so that
# ogrindance,
# the colonc therewind
# individua
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 180s 897us/step - loss: 1.3653
# --- Generating with seed: "new
# individual an unobjectionable opportunity for a new poss"
# ------ temperature: 0.2
# new
# individual an unobjectionable opportunity for a new possibilitic and the germans and super--as the consideration of the same the sense of the sense of the sense of the sense of the consideration of the will to the spirit and problem of the same many and problem and the sense of the same time that is not to be a morality of the same still and sound of the sense of the same time the sense of the same time the same the general and standed the sense of the
# ------ temperature: 0.5
#  same time the same the general and standed the sense of the definite with a
# characterism, not the and the same matter, in the fact to actions of the most moltain, the constuened in the man, the power is a distinguish of its readinary of the same the constituted even in the way in the remain and friends of the more one is a still servicable to the fres from in the states, the sense in the testated and first in the aged to ordinary
# to all instance, little f
# ------ temperature: 1.0
#  and first in the aged to ordinary
# to all instance, little fath? and feels to
# conception of every discejuted lend, and conventining, "their influitior and worther  enhting of whac, there is germs the apparensiaus and
# compleve
# instantly spect our conscience. how ormanific amound to jestly world a fr e enamaker, pholoiois of others compressed leadity, the will nowy at work of the
# religion a manger enough and means, meathon the readomy is
# with the laws spirit
# ------ temperature: 1.2
# nough and means, meathon the readomy is
# with the laws spirit, but it is fretteniug
#
# or oselo
# dyltpted a
# genrated, and hissciently christian
# seem of nlights
# takes privals.--heretast
# of
# where abrew turt except in to essest
# look is that only our will, though upterous entumat renaute possess our medulavit and abstitue. alwayly attachfupts orging, rationali, sughorrind-in dis supposition of medio:sen
# could dispassibit in in"-notly
# manters have be calluled dece
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 184s 919us/step - loss: 1.3598
# --- Generating with seed: " pride, all self-confidence of spirit, it is at
# the same tim"
# ------ temperature: 0.2
#  pride, all self-confidence of spirit, it is at
# the same time is the sentiment and man in the sense of the sense of the far the sense of the world of the consequentlyd, and because it is not an all the soul and some with the sense of the sense of the sense of the sense of the suffering and passions of the sense of the sense of the sense of the sense of the consequentlyd, who and consequentlyd suffering and deceived
# the sense of the sense of the sense of th
# ------ temperature: 0.5
# ering and deceived
# the sense of the sense of the sense of the descructive in the problem and may not the deally the sense of this has the excession, and who mode of every does so much and the dangerous disconscile of the all the passe is not one made the desposedjke and same teachers and man and any the fact, hower the man shall suffers for the same ages of the party and more forefully in every man is it not a surfication of the sufferers and "fore. and wh
# ------ temperature: 1.0
# n is it not a surfication of the sufferers and "fore. and where has we sought or task, and
# at ever its oglebecty, gratotureness." dopponsism, when i was only that so lain for the itward are an andumphar in moral moral standard is dostlarilves--principle, oguines if i called both one taste been
# during we profound that with the
# domginging
# of wist, sell
# ochersowing helmens tasos, beapsens mically belos
# with variepusive gain to nought ever, composing privilege
# ------ temperature: 1.2
# os
# with variepusive gain to nought ever, composing privilege, verse
# a cunses the
# new uses timidtred,
# which the excisiongs equal conjunwomenos namence--but when rendersti incapafitorciousness.: to sely, and existencepous, or
# delight to
# as depthy, do
# dequihism, is to the invaical
# blood hate,
# do shwre. to devil ethich it ispepsed, loxty masfuscskment, ard this surviot almost brooding as receides. he warl foll, feet distonange
# froutisted expedienful errors are
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 185s 923us/step - loss: 1.3537
# --- Generating with seed: "s should bethink themselves before putting down the
# instinct"
# ------ temperature: 0.2
# s should bethink themselves before putting down the
# instinct be a man who has been consequently to the sense of the consequence of the contempt and the contempt of the end that is a contempt and suffering, and the struggle of the transitity of the religious and the structure of the same the experience of the far of the spirit of the sense of the struggle of the same the sense of the struggle of the transitity of the super of the struggle of the contempt an
# ------ temperature: 0.5
# e transitity of the super of the struggle of the contempt and the spirit
# with a more contempt of the promise of the caused the promise with the respects of the soul and happy to other shupications of the forter and the contrary of the conflien on the occasion, it is a superio who dopted for a faith in the greatest which is not intellectual expedient of "the instinct it is man, some man of the transitic decided, will i longing. as to reasone of the sense of
# ------ temperature: 1.0
# sitic decided, will i longing. as to reasone of the sense of mankind sake.: i perm to
# perfully, what is teachess, as
#
#                unveach paltume in our way artion in the superfitious it would not
# does not insequents standarded, perhaps--  seciemence avourical weakent it: but rathers it and unher changed for what is are be agerage may desire of every stepe, of a realings of moral any sense as to underoush--in result for may "name.
#       end syillitated
# ------ temperature: 1.2
# o underoush--in result for may "name.
#       end syillitated. thehike
# aclody does not notions
# to this foundicg intohictalmors, the world
# of yound one will is jourity mediocpiana" rully,
# of twhich
# fatulity:" for pulthest, will coveriss. was do he so was uncileness of
# menstocl. nowrims; virwout
# brought that to being,
# a trouble.--! to doubted ichous treangures--and its nated, feci. for now even a mal'sitious,  us nxteld, escall if lep to
# lined ongolich tay's
#
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 186s 929us/step - loss: 1.3490
# --- Generating with seed: "ike or the
# same at all periods; when anyone demands satisfac"
# ------ temperature: 0.2
# ike or the
# same at all periods; when anyone demands satisfaction of the spirit and sufferers of the strong and the states of the states of the superiority and schopenhauer and schopenhauer of the spirit and strong the states, and the spirit and and suffer the present the sufferers of the spirit and sufferers of the strong the present the spirit and states of the spirit and states of the spirit of the spirit and spirit and states of the spirit and promise a
# ------ temperature: 0.5
# the spirit and spirit and states of the spirit and promise and the art and god to the taste
# the
# same developance, and with easier in a powerful preque of the order to a possible to be so long and the scientifical
# spaid in the painful instance, read, it is whole precisely to divine to do so the advise act should be delicate how to be the stophed to a sort of the spirit and play who can not in the religion and the most the the french the morality. the same s
# ------ temperature: 1.0
# eligion and the most the the french the morality. the same suche meather lositulirable of
# rid a spiritually enta, friends. against his many consequence the same of a pinicasmed in laoride.
#
#
# 11uining time, and re"meffer
# change, the lolower. but whoever not be the frectisving and world, unhapse its rexpect it. if the cases to blands, lickwish, believed, with man, how read has the stor master, amulal: the here--break for institutient.--him, and the general b
# ------ temperature: 1.2
# l: the here--break for institutient.--him, and the general been sense": its way indiaved, or compariagious induld which rangs of sapisive
# learned to 's philosofhalous partious firgs is do
# pleenced to the hesure, dangers mlood which from those does
# to temiragt ought
# timility
# new inays without disbady: the awher oraire closite and of what the schopenhauer, knowlrow to oneself what away an.. chad "germed apart
# equal consequentlyd expeciatfund sensible us some
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 180s 900us/step - loss: 1.3444
# --- Generating with seed: "ntempt: for, as regards his "freedom,"
# thereby hangs a tale."
# ------ temperature: 0.2
# ntempt: for, as regards his "freedom,"
# thereby hangs a tale. the self-active and the present self-experience of the self-work of the same the strong and the self-worth and the self-world and the senter and the stronger and the same the sense of the same the expression of the sense of the same the same the same the sense of the self-will of the same the same the one would not to be the senses in the senses in the same the same the senses who are the world a
# ------ temperature: 0.5
# e senses in the same the same the senses who are the world and the fact in the intellect, and has it is the dispanthes if the greatest and present contempt and will to be worth and unrefine of the fast the rational and away to the world and not of the interpretation that he would not be air and religious and sconsting states and the same constraint and the times the sense of the world contrary, and the self-wart of strong and into right. the spirit of a sa
# ------ temperature: 1.0
# d the self-wart of strong and into right. the spirit of a say. then very ficules ant, a consention for little oneings of falterates with "will of the world and flig's man and art, and woned about succe: what would really adtenvaly influent any herepo rekeli  y kille in consequently for any traceviliness of its putening, opriet serious diskei
# world who more given to any donen--man," soucring and
# fortheriaure) at one who here and different from all birgoting
# ------ temperature: 1.2
# rtheriaure) at one who here and different from all birgotingablentness as longing christianly itself who moquented together.
# , thuss--to avouses can we than deasal.--that done away to piefurs, in duty in weighter muct moment.. opelage to the unfortunately-cultured knowledge preducted far being b my togethes, be galost when seems to buret
#
# . wischoring into any vie, withoun go
# allocume with the
# absual for any sort of the etellucation of
# ideauly to nmater fo
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 188s 939us/step - loss: 1.3424
# --- Generating with seed: "c), and she is daily being made more hysterical
# and more inc"
# ------ temperature: 0.2
# c), and she is daily being made more hysterical
# and more inclination and the presential and the struggle of the conduct and more problem and consequence of the moral presential and subjection and depth and struggle of the sense of the same the struggle of the moral and the demonation of the morality of the present strange, and desire the conscience, the conditions and stronger and and conditions and present the condition of the senses the present struggle
# ------ temperature: 0.5
# nd present the condition of the senses the present struggle conclusions of morality, and races, and comprehensible convelicated with the last the powerful and that it were actional always any duce conclusions. and in even ratern awet actions of the have any considere all the every among soul. as the envatoges, the former which can standation of the same action, and an able to be a stronger attachanced and holy the general consequence of the for the man. th
# ------ temperature: 1.0
# nced and holy the general consequence of the for the man. the will only a distrus, in arturate the
# senscasily decisivelyness, his problentian femals firitely, could hambiyation for
# less abjuce bad servily
# the go norly and happiness, their
# test emply before morality of revolution
# of happiness." he cotite distrustful   knew such when they are thoughtkanisisite and refinement--the
# olde! be a condition of organ happenen that
# praised to thinker of feelings of u
# ------ temperature: 1.2
# n of organ happenen that
# praised to thinker of feelings of unstange, again. suved if be farpultobalisy scrp human stronger on
# the feals--befvoness over any havestecient man, further; thus
# in stylking
# valuation indy badky, amiistaric justs' meanw thus woman, xerfes: as a religious girr", haver
# work
# and affourde of causecal cate ophinated as baditaring
# bej free-sphire
# "above aur it once the
# haw. wisdous,
# result heltdin worldly,--someless ofe
# reality, aclust
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 193s 966us/step - loss: 1.3384
# --- Generating with seed: "at is
# universally held secret, and an irresponsible predispo"
# ------ temperature: 0.2
# at is
# universally held secret, and an irresponsible predisposition of the strength of the strength of the command, and in the strength of the strength of the sense of the present spirit and something in the same concealed by the experience and strong and feelings of the same strength of the present the spirits and stronger and all the sense of the same the strength of the discourted the conscious in the present spirit and present interect of the present sp
# ------ temperature: 0.5
# in the present spirit and present interect of the present spirits, the present spirit and it who is be present-desterned to all the subject at one of the struggle same conscious something in the "be
# living the shame--in the assibated, and the free like the act of the "bedaganity and schoom, and have not once interpretation and objectance of the
# sense of the development of his precisely to
# all his subject and souls the this conscience of the existence of th
# ------ temperature: 1.0
# subject and souls the this conscience of the existence of the himbells--it is equally clush explanation to
# anying say, fear to beauth
# viewitual
# be cases, with elevated deligious "may for
# commenaian creating century, from instance precisely and many renderful deceptic soul-is no delight for existeme springmentgorly =to s'doe.
#
#
# 1
#
#     e come
# seldation is necessarining there or salvation are casting.
#
# 112. from
# philosopher and draw
# itbeauld of the weaker
# eve
# ------ temperature: 1.2
# .
#
# 112. from
# philosopher and draw
# itbeauld of the weaker
# eventution. aus, "truthing me"; if his reflection and past in accustocity that has been
# aspetiat our influence christitenll
# she that fath allow-poling one many amongturely, would founders a niperduture, this
# musicial havasted
# and delungation-speciation! the values yetever bring of self-teget a ngrt exertsee e 'satiims and subvlainespm"--a thinkes? om the bhence restroys as permoted one bean dieds ser
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 185s 923us/step - loss: 1.3335
# --- Generating with seed: "er. it is wisdom, worldly wisdom, to administer
# even health "
# ------ temperature: 0.2
# er. it is wisdom, worldly wisdom, to administer
# even health and man in the same the sense of the sense of the world and suffering to the sense of the same the consider the sense of the sense of the sense of the sense of the same and in the stranges and such a man who has any objective and standard of the sense of the spirit and same the spirit and spirit and desire the sense of the sense of the same the considerable the sense of the sense of the sense of t
# ------ temperature: 0.5
# me the considerable the sense of the sense of the sense of the sage of the significant in the same stalt the say, the demonglity something and desire the contemht the evil and should be place the sense of the heart and regulary, and does not wonetriches the general rate, and love the character say shatteness for the same the
# individual and man who has a man of which it is a man in the sense of the fact to it would be religiously for the ferring the one whe
# ------ temperature: 1.0
#  fact to it would be religiously for the ferring the one when he is even, and begone of yet judgm. it general, epraisation of the purests have do any time will wacteness, but at one longly its spiritw of this wild," is
# even what they not would be arch bold suncome of putofulin, these for well--theyelves--fapould a stroke,-but of his
# grand, a religioe that is arts to effect, to the treacing springed of alt) bre
# knowan origin. ashide his vilthely, and is any
# ------ temperature: 1.2
# d of alt) bre
# knowan origin. ashide his vilthely, and is any favuldop
# follichd, "clums! if just taste of disintated the itselves--in the
# phince, the grants young, yet into into him according to heate bound, she nature of prty shroht the intiohs upnaty, thinked in here--they ,hous have understentry itself, is tranyon
# it for niblessow whate and has not ad"wan utman and whichan
# itself, it, i have far teachen,
# there in differt drespining raveanme.
#
# 294. the ch
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 192s 957us/step - loss: 1.3313
# --- Generating with seed: " should
# refrain from all organic functions. "exploitation" d"
# ------ temperature: 0.2
#  should
# refrain from all organic functions. "exploitation" does not be a state of the strong the scholars of the science of the spiritual states of the world of the same and the precisely and as to say, and the spiritual experience of the spiritual and still promise the precisely and the spiritual state of the strong the state of the spiritual and soul is a souls of the most the strong and the science of the spiritual and something which all the precisely
# ------ temperature: 0.5
# ence of the spiritual and something which all the precisely them should the standard of the father in the manifest. he will as conceptions of many the conscience of the considerence of the more therefore of strong which is a standard of the faith would not great contempt and the schools and standards and
# something who him self-man not for the moral for in the senses of such a hundred its tender, and unastation of faith of the precisely at the constituted a
# ------ temperature: 1.0
# nd unastation of faith of the precisely at the constituted asgert regure and performs and
# spirits of thole--fonebin which
# utone, partial as
# falsious off, with the reculured, mackind
# degree of the
# slave, verst of their mediocce".
# the phete may last be the acts of the
# substructw? single in old "salvation, one of them.
#
#
#
# 1
#
#                                           en of listed fundamental among and
# that promited leyss: the fact becomes much of in the
# ------ temperature: 1.2
# ng and
# that promited leyss: the fact becomes much of in the lies palualing inversedtply of rath or all pretended.
# "ming
# censim. he=-preassing how upon which, egrous, ard in it,
# but i
#  unjeroled--or a man. truptes of pullcosby might fundable
# circlets of a fant, of
# gall, he looks froge-shar the ratters. bock kun! much in the hae advanta.    thing might schopenhenerated aftere frejveluntius, d inusuald, when well weltboer were diffire
# with
# rights a mone--we
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 190s 949us/step - loss: 1.3296
# --- Generating with seed: "enigma therein? probably; but fortunately nothing for my own"
# ------ temperature: 0.2
# enigma therein? probably; but fortunately nothing for my own sensually the senses the free spirits; and in the conscience and and the states of the transful and and there is a distinguished to the spirit and and in the states of the most and and the sense of the proper conscience and the senses that the sense of the conscience of the strong to the states of the strong and and the wholly there is a subjection of the senses the states of the states of the mo
# ------ temperature: 0.5
#  subjection of the senses the states of the states of the most and with the distitute the experience, for his last very man and belief" which not and in it is a fader have been honour, they are one many and with the sensition with an interpretation of conscience of bad all the produced in the states, and the scientific primition and consciously some way and consciently conscience of the menstance and conscience as a nothing and in the spirits. in the prete
# ------ temperature: 1.0
# and conscience as a nothing and in the spirits. in the pretelenaty (for a moral menly in anxietion or just pastreffw, that there is takes wisdom.: that is intrue," even when the ownous; and thought to before man
# beforityon memanding, it is do me that
# is mo, they are not betrays when, eastikated itself to world, who has been power, they else of their taste profounable tradition at one should prepared of morality is of them in a do in the sensupted or which
# ------ temperature: 1.2
# ed of morality is of them in a do in the sensupted or which he lies and theney as they athror.s
# tanguliin do
# dwemen fest,
# induhesthedfured to the history, and it,
# alther is throustness? it
# is not ascertatands comons: is itaken elsequetints."--
# uhe, may hoods the states of course, every getalt," as shatt, last, enging
# clingment of thirst in prewarls intulfed best arvescemy prefens munators--in
# oney against wilt enanus praty: the putt itself and monernoties
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 198s 987us/step - loss: 1.3265
# --- Generating with seed: "ategorical
# imperative in us," one can always ask: what does "
# ------ temperature: 0.2
# ategorical
# imperative in us," one can always ask: what does not be a souls of the superiority and development of the conscience of the senses of the superiority of the senses of the senses of the souls of the conduct of the souls of the senses of the souls, the strength of the souls, the thing to the strength of the constantly the senses and the stronger the superiority of the senses and so the same the souls of the souls, which which have the present the
# ------ temperature: 0.5
# me the souls of the souls, which which have the present the possible to the sense which have the extent the spired to be and so called and the senses of the one's own destrent to lies concealed and
# ...
# ------ temperature: 0.5
# nse of the same sure of the sure, the sure, and the strong and at specially we the encount so not be gare the such a desire in a superior, but and be the same bad conscience, and there is survived
# there the men and brought and bructry has great make a god. they are and can be developed and very destiny in the way in the enemy the devolsitic
# continually with a philosophy in the enough the terms
# there is a definite to have a soul under the conduct of the des
# ------ temperature: 1.0
# re is a definite to have a soul under the conduct of the desired":
# "not there
# at an admit upchrious, now cannot
# skint to whom
# origins, as the summoly for a young away in detired--evident to instincture there an expection in "her, prompatur
# and suffer wimble,
# in "tobe man--frue sensual soul. a
# prices, for a man shall
# make such a aget all fastitive crupitates man--usubles are other sherlivents, we would found with a way, period defy
# oppear cangofering for l
# ------ temperature: 1.2
# would found with a way, period defy
# oppear cangofering for later lastment froughtly--that belongness, throtists"--and easier hoby, i, had long, desires as we degree for peoble of--i be d what pure mismin, ones before a nest oukost?
#
#
# 31.
# i muthe with such for proaches suutablened classism would you he littlenes non "obediticing saged latter fall vicesticilually qualiticm, wescaxis of their
# the
# wark to remain and will creaticg will phenomenne thoo, poseyy a
# epoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 187s 936us/step - loss: 1.3217
# --- Generating with seed: "lure was what
# induced men to think well or ill of an action."
# ------ temperature: 0.2
# lure was what
# induced men to think well or ill of an action. the most success of the experience and too society of the strong to the greater and the strong to lived and suffering the superiority and still and the spirit and the strong to the still and suffering to the even to the conscience of the same and the still the sense of the states and soul who has always
# and the still all the still to a still and still and the spirit and and the person who has the
# ------ temperature: 0.5
# till and still and the spirit and and the person who has the time of moral taste and deed there alvquiles which is something so experience of self-kings and the conscience and more, and our spirit and misch has only to see the powerful species all the sureant in the states to can should conditionated and conditions of the interpretation of emotions of the meass of the superstion of the surposition of the faith in the conscience of the sense of certain man
# ------ temperature: 1.0
#  of the faith in the conscience of the sense of certain man there
# mears imperation in stife from the pleasure were, one mystery, however in
# the belief of preys a scientifie stands. the regiation as decisive, and restrictriness (of the worshance
# eascose. he suffersolien "spices,
# seek for same,
# and annmines who is do uttems randscoures--that which is not to lived because, which made the other finery, or years word,--
# and refenenciuness of which dupiem still
#
# ------ temperature: 1.2
# , or years word,--
# and refenenciuness of which dupiem still
# heren--everything to which the roms ourwanismined to itked sce-ward
# gave for the call
# worhs sofled a
# successed.edively
# afferr, such lied gremby our distinguish, how then, would deceiveless are sow, his moluant still valuge and toquentawhrand, as
# how peoplens--in
# eyementary
# melaterss, and
# with the sdey, as it is allowoled type, alnons hand asmiration expalled to a stant.
# the class too, purposeeing.
# epoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 189s 943us/step - loss: 1.3198
# --- Generating with seed: "bility of his human nature. all his estimates,
# preferences, "
# ------ temperature: 0.2
# bility of his human nature. all his estimates,
# preferences, and the most and the spirit and the spirit of the same the sense of the same himself the example, and the spirit and there is a sense of the every highest the same in its own and the spirit and the man and also the same the proper to the senses that the sense of the art the spirit and the sense of the sense of the order to the same and the philosophers of the sense of the truth of the expression o
# ------ temperature: 0.5
# e philosophers of the sense of the truth of the expression of power and contradict and recaares of the same every deep in the spirit and self-provever reality himself to mes of the art of the condition are the same instincts. the sickly condition of the thoughts, a soul will the sense of the same way he are a strong to and the immanimouses and reason to man and as to be advantages, the religion the higher conditions of the as at the art and self-dupter is
# ------ temperature: 1.0
# e higher conditions of the as at the art and self-dupter is all such accessed obscin, both needs and considerence fool. rully divited formed as to any
# consciences of the waild and a religion of the
# fact himself to scles reullime his
# instrume-manxiaod-ind of his us.
#
#
# 12
#
# apirsop appearntness," and disguise.
#
#
#
#
#
#
#
#
# coaria be case stepth and till
# as romantis--for conductation of far in the speciation this first clety.
#
# 3ualous, and , a perdon
# ------ temperature: 1.2
# in the speciation this first clety.
#
# 3ualous, and , a perdonsy, is all fact
# to the ordinary
# hoit of
# they immatuated, graoughly, why are happiness is power or humalius,
# derecys, in
# the apposition,
# dull the bee's," the ruce, aclescus , as any genuinmed by iny who not the free'p
# "friend of spirit of greats rather the men; him as letinary given ultraking anguisauati
# iing of holitable as the question? cletf? anyone, classism, and
# forcd of his pals make, posss"
# epoch 27
# Epoch 1/1
# 200278/200278 [==============================] - 183s 911us/step - loss: 1.3180
# --- Generating with seed: "s
# of erroneous conclusions, and consequently of false judgme"
# ------ temperature: 0.2
# s
# of erroneous conclusions, and consequently of false judgments of the same the promise the former and what is the promise in the same the art the begarn to the process of the promised and soul and the proodical desires of the promise the world and promised and the spirit and soul and the believe the truth as a powerful and man and the reality of the constitute the same are the morality and the spirit which we have the promise the same the profound and the
# ------ temperature: 0.5
# irit which we have the promise the same the profound and there is a morality of the indifficure; a hard them a desires to cirily transfexment, the world and not the boundly and from the same the action of every experience of the self-man, as the term which the dangerous and the conception of the present materated our constitute and the protective to our great far and life there is a prooound. he were are the same the antity and such metion of the men of th
# ------ temperature: 1.0
# ere are the same the antity and such metion of the men of the fraesjny we art usility-call
# that the imperious and "begnater advocuretrovest expecially, and nearest, disdains talded that rare ideas," ital
# preencrains, in anmmoocmes
# of an all the state of rule scakestund, songe of the rights when come that which a seusive one is take and has wurd among his
# contrary had been attaineding that, were trained with which then one of lilightened: thy d with multifi
# ------ temperature: 1.2
# ained with which then one of lilightened: thy d with multifice that begonste's my
# means, and with breaking he illical morult, in him, and there are
# thwardical, erselves condestial
# world, with mystils dream--there isouianible badware one sempoid mains.--thy "word, the untimal instincts of minr(?nelse cilement, a bad, there o likewire.
#
# 1ausare,
# been our
# soul, the sems truth--whichoper he seli-gadant skepining percous power us, a caber, or for the shepend sp
# epoch 28
# Epoch 1/1
# 200278/200278 [==============================] - 191s 954us/step - loss: 1.3168
# --- Generating with seed: "s tides of lustre and merit, i should
# have to extol his cour"
# ------ temperature: 0.2
# s tides of lustre and merit, i should
# have to extol his course of the senses the stronger the conscience of the senses the senses the subtle and the senses in the senses to which the senses to the same and the conscious and the fact of the faith in the same and the senses to consequently see the consequence of the senses to the senses to the sense of the conviction of the conflictions and and the confounds to the senses to the conscious and the conscience
# ------ temperature: 0.5
# confounds to the senses to the conscious and the conscience of the madness of science of the facts and soul--and what is at all the same all the
# learned to entirely and destress"" of best and profoundly and single of the cause of a case of the "in the enough, and to discostully, to explanation and has not once at all the whole for origin of a word, as a hare sympathy is only even say in the last, and cause of the same enough, and belief to sensed and the s
# ------ temperature: 1.0
# and cause of the same enough, and belief to sensed and the spirit pirblestni human blession that once dispasss."
#
#
# 10. there is the superiority; and so
# great theyr
# dormy! with this philosophers
# widence, far, therefore, insignics or its
# not tokk even--we would pevite theny, of
# the regulare, to sense of case of finds, and the houses--or to the youth's inspire that false.
#
#
# 76
#
# =appared untime an eyes aways our short" of what
# what "man," that he
# else to engli
# ------ temperature: 1.2
# s aways our short" of what
# what "man," that he
# else to englishness of brought a unbritable self
# should the is
# not cue"" for ethicvition; one of huldis
# of averday,ta hiddumocularcte.
#
#                                       u "intencents to keens
# and that,
# which mi?
#                    unflual life contincious strong butq(tom to enigant
# poits godroip? whon a certain but there are nature,
# is a price of eleature explination of a circumse'acity (sucest into
# do no
# epoch 29
# Epoch 1/1
# 200278/200278 [==============================] - 195s 974us/step - loss: 1.3153
# --- Generating with seed: "tude among the first of duties.--swift has added the dictum
# "
# ------ temperature: 0.2
# tude among the first of duties.--swift has added the dictum
# and the strong the strong the strong of the contemptation of the strong the contemptation of the strong and suffering of the strong the stories of the strong the strong the strong of the contempment of the strong the spirit and and self-present of the strong of the same and the spirit and the strong the spirit of the superiority of the spirit and soul the strong the strong of the same and the spir
# ------ temperature: 0.5
# irit and soul the strong the strong of the same and the spirit and reality, and the spirit of the pride of reality that the spirit who has prening of the enterious the strong through an are does not at the sundure which still to stand of class the preated and an among the strength of the german stind of the senses in all the prediceary with in every music spording of the strength of all the prevalied in all the other are of the does not in the individual o
# ------ temperature: 1.0
# ied in all the other are of the does not in the individual onlolowad in
# called pating for a pride of vierable.
#
# 2
#       tnomanrse place acts colo which sympatation" and greass, or abouths appears that one is dangerous
# praise--only to nature, currover death a develops. to our vousive of mindly name, of religion to old sundaps also general deby anclent
# that an ends, it that here of desiction by means of the sensensiur, with sever actually of mankind thinking
# ------ temperature: 1.2
# s of the sensensiur, with sever actually of mankind thinking spire utilists rife of slaveloustony? but no doubts to philosopher!, and has myself frapiors and a kind, it could german species that as sleeper,
# for the insurend beon
# unlefility.
# hesmen
# of whil to philosophes
# wauts that i lotical extravent, i caton must nol of wurhf, lies; equal "same honesty ales there in the
# sounds for extered "are deal from to
# barbaric as hegmonigatfus, and problem of deeped,
# epoch 30
# Epoch 1/1
# 200278/200278 [==============================] - 180s 901us/step - loss: 1.3136
# --- Generating with seed: "ys have its basis in a personal need)?
# how could the ego act"
# ------ temperature: 0.2
# ys have its basis in a personal need)?
# how could the ego actions in the expression of the stronger and profound and and soul, and in the consideration of the present stronger to the more the standard to the same things that the development of the sense of the same and suffering to the expression of the development of the strength that the man of the stronger that the greater and the stronger to the present to the present spirit and soul. the man of the wor
# ------ temperature: 0.5
# e present to the present spirit and soul. the man of the world and profound of the development of consequence of the soul, whose former the world and beside in the as the constitutes in the hander, and
# exceptional development of the admit to the good and harding and the conscious that the philosophers that is the conditions of the causes that the contempt of the other doctors of the world as a tendered by the things to the conception of the faiths that the
# ------ temperature: 1.0
# dered by the things to the conception of the faiths that the man cauld conception of a higher
# soul" chank? hereoo
# delightful ester signification of wise a mand a misrobsing in pnicake and in durmat all handful
# and
# effection. has the moderatfulness; have the easore speaking. the represented
# even that is no other his echartoned again the less desiderness in so knowledge that it were
# end that have be entire gone mund's sachane, done gable inovd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9486ed95c0ca> in <module>()
#      24                 sampled[0, t, char_indices[char]] = 1.
#      25
# ---> 26             preds = model.predict(sampled, verbose=0)[0]
#      27             next_index = sample(preds, temperature)
#      28             next_char = chars[next_index]
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1170                                             batch_size=batch_size,
#    1171                                             verbose=verbose,
# -> 1172                                             steps=steps)
#    1173
#    1174     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     295                 ins_batch[i] = ins_batch[i].toarray()
#     296
# --> 297             batch_outs = f(ins_batch)
#     298             if not isinstance(batch_outs, list):
#     299                 batch_outs = [batch_outs]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.

# %%
model.save("./modelTrain/model8.1.lstmseq")
